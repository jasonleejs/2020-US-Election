# %%
# Libraries for Data Manipulation
import pandas as pd
import numpy as np

# Libraries for Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob

# %%
trump_df = pd.read_csv('../data/hashtag_donaldtrump.csv', lineterminator='\n')
biden_df = pd.read_csv('../data/hashtag_joebiden.csv', lineterminator='\n')

# %%
# Check shape of both data frames

print(trump_df.shape) # trump_df has more rows by ~200,000

print(biden_df.shape)
# Out:
# (970919, 21)
# (776886, 21)

# %%
# Check the Info of dataset

print(trump_df.info())

print(biden_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970919 entries, 0 to 970918
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            970919 non-null  object
#  1   tweet_id              970919 non-null  float64
#  2   tweet                 970919 non-null  object
#  3   likes                 970919 non-null  float64
#  4   retweet_count         970919 non-null  float64
#  5   source                970043 non-null  object
#  6   user_id               970919 non-null  float64
#  7   user_name             970903 non-null  object
#  8   user_screen_name      970919 non-null  object
#  9   user_description      869653 non-null  object
#  10  user_join_date        970919 non-null  object
#  11  user_followers_count  970919 non-null  float64
#  12  user_location         675966 non-null  object
#  13  lat                   445719 non-null  float64
# ...

# %%
# Concat two datasets for easier analysis
trump_df['Candidate'] = "TRUMP"
biden_df['Candidate'] = "BIDEN"

mixed_df = pd.concat([trump_df, biden_df])
mixed_df['created_at'] = pd.to_datetime(mixed_df.created_at)
mixed_df.sort_values(by='created_at', inplace=True)
mixed_df.head()
# Out:
#            created_at      tweet_id  \
# 0 2020-10-15 00:00:01  1.316529e+18
# 0 2020-10-15 00:00:01  1.316529e+18
# 1 2020-10-15 00:00:01  1.316529e+18
# 2 2020-10-15 00:00:02  1.316529e+18
# 3 2020-10-15 00:00:02  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1  Usa 2020, Trump contro Facebook e Twitter: cop...   26.0            9.0
# 2  #Trump: As a student I used to hear for years,...    2.0            1.0
# 3  2 hours since last tweet from #Trump! Maybe he...    0.0            0.0
#
#              source       user_id           user_name user_screen_name  \
# 0         TweetDeck  3.606665e+08  El Sol Latino News  elsollatinonews
# 0         TweetDeck  3.606665e+08  El Sol Latino News  elsollatinonews
# 1  Social Mediaset   3.316176e+08             Tgcom24  MediasetTgcom24
# ...

# %%
# Plotting the number of tweets for Trump and Biden
mixed_df.groupby('Candidate')['tweet'].count().plot.bar()
plt.title("Biden vs Trump")
plt.ylabel("Number of Tweets")
plt.show()

# %%
# Comparison of Likes
mixed_df.groupby('Candidate')['likes'].sum().plot.bar()
plt.title("Biden vs Trump")
plt.ylabel("Number of Likes")
plt.show()

# %%
# Showing number of Tweets from each country
mixed_df['country'] = mixed_df['country'].replace({"United States of America": "US", "United States": "US"})
mixed_df['country'].value_counts()
# Out:
# US                          394400
# United Kingdom               58051
# India                        40091
# Germany                      35379
# France                       35299
#                              ...
# Mali                             2
# Northern Mariana Islands         1
# Saint Lucia                      1
# Lesotho                          1
# East Timor                       1
# Name: country, Length: 188, dtype: int64

# %%
# Comparing number of Tweets from countries
plt.figure(figsize=(18,10))
mixed_df.groupby('country')['tweet'].count().sort_values(ascending=False).head(10).plot.bar()
plt.ylabel('Number of Tweets')
plt.title('Top 10 Countries with Highest Number of Tweets')
plt.show()

# %%
# List of Top 10 Countries with highest number of Tweets
top10Countries = mixed_df.groupby('country')['tweet'].count().sort_values(ascending=False).head(10).index.tolist()
top10Countries
# Out:
# ['US',
#  'United Kingdom',
#  'India',
#  'Germany',
#  'France',
#  'Canada',
#  'Italy',
#  'Australia',
#  'Mexico',
#  'Turkey']

# %%
# Showing Tweets for each candidate from each top 10 country 
tweet_df = mixed_df.groupby(['country', 'Candidate'])['tweet'].count().reset_index()
tweet_df = tweet_df[tweet_df['country'].isin(top10Countries)]
tweet_df
# Out:
#             country Candidate   tweet
# 16        Australia     BIDEN    5534
# 17        Australia     TRUMP    9365
# 54           Canada     BIDEN   10809
# 55           Canada     TRUMP   16996
# 112          France     BIDEN   14610
# 113          France     TRUMP   20689
# 118         Germany     BIDEN   12761
# 119         Germany     TRUMP   22618
# 146           India     BIDEN   21532
# 147           India     TRUMP   18559
# 160           Italy     BIDEN    8870
# 161           Italy     TRUMP   11206
# 207          Mexico     BIDEN    5092
# 208          Mexico     TRUMP    5811
# 336          Turkey     BIDEN    4774
# 337          Turkey     TRUMP    5594
# 340              US     BIDEN  181137
# 341              US     TRUMP  213263
# 348  United Kingdom     BIDEN   23308
# 349  United Kingdom     TRUMP   34743

# %%
# Plot top 10 countries' number of tweets for each candidate
plt.figure(figsize=(18,10))
sns.barplot(data=tweet_df, x='country', y='tweet', hue='Candidate')
plt.show()

# %%
# List of top 10 states with highest number of Tweets
top10States = mixed_df.groupby('state')['tweet'].count().sort_values(ascending=False).head(10).index.tolist()
top10States
# Out:
# ['California',
#  'New York',
#  'England',
#  'Texas',
#  'Florida',
#  'District of Columbia',
#  'Ile-de-France',
#  'Pennsylvania',
#  'Illinois',
#  'Ontario']

# %%
state_df = mixed_df.groupby(['state', 'Candidate'])['tweet'].count().reset_index()
state_df = state_df[state_df['state'].isin(top10States)]
state_df
# Out:
#                      state Candidate  tweet
# 206             California     BIDEN  25817
# 207             California     TRUMP  31149
# 349   District of Columbia     BIDEN   7055
# 350   District of Columbia     TRUMP   9684
# 386                England     BIDEN  16743
# 387                England     TRUMP  24111
# 410                Florida     BIDEN  13284
# 411                Florida     TRUMP  16568
# 518          Ile-de-France     BIDEN   7001
# 519          Ile-de-France     TRUMP   9393
# 520               Illinois     BIDEN   5500
# 521               Illinois     TRUMP   6777
# 794               New York     BIDEN  21005
# 795               New York     TRUMP  22881
# 869                Ontario     BIDEN   4492
# 870                Ontario     TRUMP   6907
# 899           Pennsylvania     BIDEN   5403
# 900           Pennsylvania     TRUMP   7011
# 1154                 Texas     BIDEN  14191
# 1155                 Texas     TRUMP  16491

# %%
plt.figure(figsize=(18,10))
sns.barplot(data=state_df, x='state', y='tweet', hue='Candidate')
plt.show()

# %%
dates_df = mixed_df.groupby([mixed_df.created_at.dt.to_period('d'), 'Candidate'])['tweet'].count().reset_index()
dates_df['created_at'] = dates_df.created_at.astype(str)
dates_df['created_at'] = pd.to_datetime(dates_df.created_at)
dates_df.sort_values(by='created_at', inplace=True)
dates_df.head(10)
# Out:
#   created_at Candidate  tweet
# 0 2020-10-15     BIDEN  14949
# 1 2020-10-15     TRUMP  18135
# 2 2020-10-16     BIDEN  17950
# 3 2020-10-16     TRUMP  24958
# 4 2020-10-17     BIDEN  11469
# 5 2020-10-17     TRUMP  16958
# 6 2020-10-18     BIDEN  10374
# 7 2020-10-18     TRUMP  17480
# 8 2020-10-19     BIDEN  10781
# 9 2020-10-19     TRUMP  19945

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=dates_df, x='created_at', y='tweet', hue='Candidate', style='Candidate', markers=['o','o'], dashes=False)
plt.title("Tweets over time")
plt.ylabel("Tweets")
plt.xlabel(None)
plt.show()

# %% [markdown]
# # Sentiment Analysis

# %%
def clean(text):
    '''Make text lowercase, remove text in square brackets, remove links, 
    remove punctuation and remove words containing numbers'''
    text = str(text).lower() # turns text into lowercase
    text = re.sub('\[.*?\]', '', text) # removes text inside [ ] brackets
    text = re.sub('https?://\S+|www\.\S+', '', text) # removes link-like texts
    text = re.sub('<.*?>+', '', text) # removes text inside < > brackets
    text = re.sub('\n', '', text) # removes newline operators
    text = re.sub('\w*\d\w*', '', text) # removes text (word) that contains a number
    text = re.sub(r'\@[A-Za-z0-9]+', '', text) # removes mentions containing @ at front
    text = re.sub(r'#', '', text) # removes hashtags
    text = re.sub(r'RT[\s]+', '', text) # removes occurences of "RT" for ReTweet
    text = re.sub(r'[^\w]', ' ', text) # removes non-alphanumeric characters
    return text

# %%
# create functions to get subjectivity and polarity 
def get_subjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def get_polarity(text):
    return TextBlob(text).sentiment.polarity

def get_analysis(score):
    if score < 0:
        return 'negative'
    elif score == 0:
        return 'neutral'
    else:
        return 'positive'

# %%
trump_tweets = (mixed_df[mixed_df['Candidate']=='TRUMP']
                .sort_values('user_followers_count', ascending=False)
                .drop_duplicates(['user_name'])
                [['tweet', 'country']])

trump_tweets = trump_tweets.dropna().loc[trump_tweets.country == 'US'].reset_index(drop=True)

# Aggregating DF with cleaned tweets, subjectivity, polarity, analysis
trump_tweets['clean_tweet'] = trump_tweets['tweet'].apply(clean)
trump_tweets['subjectivity'] = trump_tweets['clean_tweet'].apply(get_subjectivity)
trump_tweets['polarity'] = trump_tweets['clean_tweet'].apply(get_polarity)
trump_tweets['analysis'] = trump_tweets['polarity'].apply(get_analysis)

trump_tweets.head()
# Out:
#                                                tweet country  \
# 0  Without a doubt, the #FourSeasons debacle is t...      US
# 1  President Donald #Trump’s youngest daughter, T...      US
# 2  Woah. Have you read this article?\n\nAll the p...      US
# 3  The latest episode of #SNL tackled #DonaldTrum...      US
# 4  🇺🇸 #Decision2020: @JoeBiden firmará una serie ...      US
#
#                                          clean_tweet  subjectivity  polarity  \
# 0  without a doubt  the fourseasons debacle is th...      0.483333  0.333333
# 1  president donald trump s youngest daughter  ti...      0.000000  0.000000
# 2  woah  have you read this article all the presi...      0.000000  0.000000
# 3  the latest episode of snl tackled donaldtrump ...      0.800000 -0.033333
# 4        firmará una serie de órdenes ejecutivas ...      0.000000  0.000000
#
#    analysis
# 0  positive
# 1   neutral
# 2   neutral
# 3  negative
# 4   neutral

# %%
# Show proportions of negative, neutral, positive tweets as percentage
trump_tweets['analysis'].value_counts(normalize=True) * 100
# Out:
# neutral     43.694396
# positive    36.258595
# negative    20.047009
# Name: analysis, dtype: float64

# %%
plt.figure(figsize=(10,5))
(trump_tweets['analysis'].value_counts(normalize=True) * 100).plot.bar()
plt.title("Trump Tweets")
plt.ylabel("% of tweets")
plt.show()

# %%
# wordcloud

# %%
biden_tweets = (mixed_df.loc[mixed_df.Candidate == 'BIDEN']
                .sort_values('user_followers_count', ascending=False)
                .drop_duplicates(['user_name'])
                [['tweet', 'country']])
biden_tweets = biden_tweets.dropna().loc[biden_tweets.country == 'US'].reset_index(drop=True)

# Aggregate DF again
biden_tweets['clean_tweet'] = biden_tweets['tweet'].apply(clean)
biden_tweets['subjectivity'] = biden_tweets['clean_tweet'].apply(get_subjectivity)
biden_tweets['polarity'] = biden_tweets['clean_tweet'].apply(get_polarity)
biden_tweets['analysis'] = biden_tweets['polarity'].apply(get_analysis)

biden_tweets.head()
# Out:
#                                                tweet country  \
# 0  #JoeBiden is enlisting A-list star power to he...      US
# 1  While we were campaigning across battleground ...      US
# 2  The big fight TODAY!!!!! @realDonaldTrump vs #...      US
# 3  News outlets have projected that #JoeBiden has...      US
# 4  During his victory speech, #JoeBiden said he u...      US
#
#                                          clean_tweet  subjectivity  polarity  \
# 0  joebiden is enlisting a list star power to hel...          0.00      0.00
# 1  while we were campaigning across battleground ...          0.75      0.80
# 2  the big fight today       vs joebiden who you ...          0.10      0.00
# 3  news outlets have projected that joebiden has ...          0.00      0.00
# 4  during his victory speech  joebiden said he un...          0.75     -0.75
#
#    analysis
# 0   neutral
# 1  positive
# 2   neutral
# 3   neutral
# 4  negative

# %%
biden_tweets['analysis'].value_counts(normalize=True) * 100
# Out:
# neutral     45.353606
# positive    40.000000
# negative    14.646394
# Name: analysis, dtype: float64

# %%
plt.figure(figsize=(10,5))
(biden_tweets['analysis'].value_counts(normalize=True) * 100).plot.bar()
plt.title("Biden Tweeets")
plt.ylabel("% of Tweets")
plt.show()
